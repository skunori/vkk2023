# %%
import ROOT
from ROOT import VecOps
import numpy as np
import sys
# Out:
# Welcome to JupyROOT 6.26/04

# %%
def deltar(eta1, eta2, phi1, phi2):
    x = ROOT.VecOps.DeltaR(eta1, eta2, phi1, phi2)
    return(x)

# %%
def getGenIndex(t):
    genIdx={}
    gen_id = t.GenPart_pdgId
    mthr_idx = t.GenPart_genPartIdxMother
    for i in range(t.nGenPart):
        if gen_id[i]==9000022:
            genIdx["akk"]=i
        if gen_id[i]==9000025:
            genIdx["radion"]=i
        if mthr_idx[i]>=0:
            if gen_id[i]==22 and (gen_id[mthr_idx[i]]==9000022 or mthr_idx[i]==0) :
                genIdx["photon"]=i
            if gen_id[i]==24:
                genIdx["wp"]=i
            if gen_id[i]==-24:
                genIdx["wm"]=i
            if abs(gen_id[i])<20:
                if gen_id[mthr_idx[i]]==24:
                    if "wp0" in genIdx:
                        genIdx["wp1"]=i
                    else:
                        genIdx["wp0"]=i
                if gen_id[mthr_idx[i]]==-24:
                    if "wm0" in genIdx:
                        genIdx["wm1"]=i
                    else:
                        genIdx["wm0"]=i

    # print("genIdx",genIdx)
    return genIdx

# %%
def myphoton(t):
    """
    find iso_photons
    input:  t= tree for this event
    output: iso_photons_idx= list of index
    """
    photon_id=t.Photon_mvaID_WP90
    photon_seed=t.Photon_pixelSeed
    photon_pt=t.Photon_pt
    iso_photons_idx = []
    nphotons = len(photon_id)
    #print(nphotons)
    if nphotons > 0:
        for i in range(nphotons):
            if (photon_id[i] == 1) and (photon_seed[i] == 0):
                iso_photons_idx.append(i)
            else:
                continue
    return iso_photons_idx

# %%
def cleanedjets(t):
    jet_eta=t.FatJet_eta
    jet_phi=t.FatJet_phi
    jet_mass=t.FatJet_msoftdrop
    jet_jetId=t.FatJet_jetId
    
    photon_eta=t.Photon_eta
    photon_phi=t.Photon_phi
    photon_id=t.Photon_mvaID_WP90
    photon_seed=t.Photon_pixelSeed
    photon_pt=t.Photon_pt
      
    jets_idx = []
    nfatjets = len(jet_eta)
    # photons = myphoton(photon_id, photon_seed, photon_pt)
    photons = myphoton(t)
    if nfatjets >= 0:
        for k in range(nfatjets):
            iskip=0
            for ip, p in enumerate(photons):
                if (abs(ROOT.VecOps.DeltaR(jet_eta[k], photon_eta[p], jet_phi[k], photon_phi[p]))) < 0.4:
                    iskip=1
                    break

            if iskip==0:
                jets_idx.append(k)
    
    return jets_idx

# %%
def print_event(it, t, alist):
    """
    alsit: list of objects to print. Available keys are,
    met
    genPart, genPart_all
    recoPhoton, recoPhoton_all
    recoFatjet, recoFatjet_all
    recoElectron_all
    recoMuon_all
    []    for all objects
    ["met","genPart","recoPhoton","recoPhoton_all","recoFatjet","recoFatjet_all","recoElectron_all","recoMuon_all"]
    """

    
    print()
    print("Event: ",it)
    
    """
    MET
    """
    def printMET():
        print("=== MET ")
        print("   GenMET pt {:8.1f}".format(t.GenMET_pt),end="")
        print("     phi {:8.1f}".format(t.GenMET_phi),end="")
        print(" ")
        print("   MET    pt {:8.1f}".format(t.MET_pt),end="")
        print("     phi {:8.1f}".format(t.MET_phi),end="")
        print(" ")
        
    if ("met" in alist) or len(alist)==0:
        printMET()
        
    """
    GenParticle
    """
    def print_aGenPart_Header(title):
        print("=== GenPart ",title)
        print("{:>4s}".format("  "),end="")
        print("{:>4s}".format("stat"),end="")
        print("{:>8s}".format("id"),end="")
        print("{:>6s}".format("moth"),end="")
        print("{:>8s}".format("pt"),end="")
        print("{:>8s}".format("eta"),end="")
        print("{:>8s}".format("phi"),end="")
        print("{:>8s}".format("mass"),end="")
        print()
        
    def print_aGenPart(ix):
        print("{:4d}".format(ix),end="")
        print("{:4d}".format(t.GenPart_status[ix]),end="")
        print("{:8d}".format(t.GenPart_pdgId[ix]),end="")
        print("{:6d}".format(t.GenPart_genPartIdxMother[ix]),end="")
        print("{:8.1f}".format(t.GenPart_pt[ix]),end="")
        print("{:8.2f}".format(t.GenPart_eta[ix]),end="")
        print("{:8.2f}".format(t.GenPart_phi[ix]),end="")
        print("{:8.1f}".format(t.GenPart_mass[ix]),end="")
        print()
    
    if ("genPart" in alist) or len(alist)==0:
        print_aGenPart_Header("")  #  print a header
    
        genIdx=getGenIndex(t)  #   get a dictionary of genpart index
        for key in genIdx:
            # print("key",key)
            ix=genIdx[key]
            print_aGenPart(ix)
            
    if ("genPart_all" in alist) or len(alist)==0:
        print_aGenPart_Header("(all)")  #  print a header
        for ix in range(t.nGenPart):
            print_aGenPart(ix)

    """
    RecoPhoton
    """
    def print_recoPhoton_Header(title):
        print("=== Reco Photon ",title)
        print("{:>4s}".format("  "),end="")
        print("{:>8s}".format("id"),end="")
        print("{:>8s}".format("pt"),end="")
        print("{:>8s}".format("eta"),end="")
        print("{:>8s}".format("phi"),end="")
        print()
    
    def print_recoPhoton(ix):
        print("{:4d}".format(ix),end="")
        print("{:8d}".format(t.Photon_mvaID_WP90[ix]),end="")
        print("{:8.1f}".format(t.Photon_pt[ix]),end="")
        print("{:8.2f}".format(t.Photon_eta[ix]),end="")
        print("{:8.2f}".format(t.Photon_phi[ix]),end="")
        print()
        
    if ("recoPhoton" in alist) or len(alist)==0:
        iso_photon_idx=myphoton(t)
        if len(iso_photon_idx)>0:
            print_recoPhoton_Header("")
            for ix in iso_photon_idx:
                print_recoPhoton(ix)
        
    if ("recoPhoton_all" in alist) or len(alist)==0:
        if t.nPhoton>0:
            print_recoPhoton_Header("(all)")
            for ix in np.arange(t.nPhoton):
                print_recoPhoton(ix)

    """
    RecoFatJet
    """
    def print_recoFatjet_Header(title):
        print("=== Reco Fatjet ",title)
        print("{:>4s}".format("  "),end="")
        print("{:>8s}".format("id"),end="")
        print("{:>8s}".format("pt"),end="")
        print("{:>8s}".format("eta"),end="")
        print("{:>8s}".format("phi"),end="")
        print("{:>8s}".format("sd mass"),end="")
        print()
    
    def print_recoFatjet(ix):
        print("{:4d}".format(ix),end="")
        print("{:8d}".format(t.FatJet_jetId[ix]),end="")
        print("{:8.1f}".format(t.FatJet_pt[ix]),end="")
        print("{:8.2f}".format(t.FatJet_eta[ix]),end="")
        print("{:8.2f}".format(t.FatJet_phi[ix]),end="")
        print("{:8.1f}".format(t.FatJet_msoftdrop[ix]),end="")
        print() 

    if ("recoFatjet" in alist) or len(alist)==0:
        jets_idx=cleanedjets(t)
        if len(jets_idx)>0:
            print_recoFatjet_Header("")
            for ix in jets_idx:
                print_recoFatjet(ix)
            
    if ("recoFatjet_all" in alist) or len(alist)==0:
        if t.nFatJet>0:
            print_recoFatjet_Header("(all)")
            for ix in np.arange(t.nFatJet):
                print_recoFatjet(ix)

    """
    RecoElectron
    """        

    def print_recoElectron_Header(title):
        print("=== Reco Electron ",title)
        print("{:>4s}".format("  "),end="")
        print("{:>8s}".format("pt"),end="")
        print("{:>8s}".format("eta"),end="")
        print("{:>8s}".format("phi"),end="")
        print()
    
    def print_recoElectron(ix):
        print("{:4d}".format(ix),end="")
        print("{:8.1f}".format(t.Electron_pt[ix]),end="")
        print("{:8.2f}".format(t.Electron_eta[ix]),end="")
        print("{:8.2f}".format(t.Electron_phi[ix]),end="")
        print() 
        
    if ("recoElectron_all" in alist) or len(alist)==0:
        if t.nElectron>0:
            print_recoElectron_Header("(all)")
            for ix in np.arange(t.nElectron):
                print_recoElectron(ix)

    """
    RecoMuon
    """
    def print_recoMuon_Header(title):
        print("=== Reco Muon ",title)
        print("{:>4s}".format("  "),end="")
        print("{:>8s}".format("pt"),end="")
        print("{:>8s}".format("eta"),end="")
        print("{:>8s}".format("phi"),end="")
        print()
    
    def print_recoMuon(ix):
        print("{:4d}".format(ix),end="")
        print("{:8.1f}".format(t.Muon_pt[ix]),end="")
        print("{:8.2f}".format(t.Muon_eta[ix]),end="")
        print("{:8.2f}".format(t.Muon_phi[ix]),end="")
        print() 

    if ("recoMuon_all" in alist) or len(alist)==0:
        if t.nMuon>0:
            print_recoMuon_Header("(all)")
            for ix in np.arange(t.nMuon):
                print_recoMuon(ix)
            
    """
    RecoTau
    """
    def print_recoTau_Header(title):
        print("=== Reco Tau === ",title)
        print("{:>4s}".format("  "),end="")
        print("{:>8s}".format("pt"),end="")
        print("{:>8s}".format("eta"),end="")
        print("{:>8s}".format("phi"),end="")
        print()
    
    def print_recoTau(ix):
        print("{:4d}".format(ix),end="")
        print("{:8.1f}".format(t.Tau_pt[ix]),end="")
        print("{:8.2f}".format(t.Tau_eta[ix]),end="")
        print("{:8.2f}".format(t.Tau_phi[ix]),end="")
        print() 

    if ("recoTau_all" in alist) or len(alist)==0:
        if t.nTau>0:
            print_recoTau_Header("(all)")
            for ix in np.arange(t.nTau):
                print_recoTau(ix)

# %%
class test_myphoton():
    def __init__(self):
        self.h1={}
        s="photon_n"
        self.h1[s] = ROOT.TH1F(s,s,10,0.,10.)
        s="photon_pt"
        self.h1[s] = ROOT.TH1F(s,s,100,0.,2000.)
        s="photon_eta"
        self.h1[s] = ROOT.TH1F(s,s,100,-5.0,5.0)
        s="photon_phi"
        self.h1[s] = ROOT.TH1F(s,s,100,0.0,4.0)
    
    def analyze(self,t):
                
        iso_photon_idx=myphoton(t)
        n=len(iso_photon_idx)
        print("iso_photon n=",n," idx",iso_photon_idx)
        
        self.h1["photon_n"].Fill(n)
        
        for i,idx in enumerate(iso_photon_idx):
            # print("i",i,"idx",idx)
            pt=t.Photon_pt[idx]
            eta=t.Photon_eta[idx]
            phi=t.Photon_phi[idx]
            self.h1["photon_pt"].Fill(pt)
            self.h1["photon_eta"].Fill(eta)
            self.h1["photon_phi"].Fill(phi)
    
    def endjob(self):
        print("test_myphoton::endjob")
        c1 = ROOT.TCanvas("c1","test_myphoton",800,600)
        print("in endjob0")
        c1.Divide(2,2)
        c1.cd(1)
        s="photon_n"
        self.h1[s].Draw()
        c1.cd(2)
        s="photon_pt"
        self.h1[s].Draw()
        c1.cd(3)
        s="photon_eta"
        self.h1[s].Draw()
        c1.cd(4)
        s="photon_phi"
        self.h1[s].Draw()
        print("in endjob5")
        
        #  c1.Draw()  # Draw does not work here...
        c1.SaveAs("test_myphoton.pdf")
        #  for testing on mac
        # !open "test_myphoton.pdf"
        return

# %%
class test_cleanedjets():
    def __init__(self):
        self.h1={}
        s="fatjet_n"
        self.h1[s] = ROOT.TH1F(s,s,10,0.,10.)
        s="fatjet_pt"
        self.h1[s] = ROOT.TH1F(s,s,100,0.,2000.)
        s="fatjet_eta"
        self.h1[s] = ROOT.TH1F(s,s,100,-5.0,5.0)
        s="fatjet_phi"
        self.h1[s] = ROOT.TH1F(s,s,100,0.0,4.0)
    
    def analyze(self,t):
        fatjet_idx=cleanedjets(t)
        n=len(fatjet_idx)
        print("fatjet n=",n," idx",fatjet_idx)
        
        self.h1["fatjet_n"].Fill(n)
        
        for i,idx in enumerate(fatjet_idx):
            print("i",i,"idx",idx)
            pt=t.FatJet_pt[idx]
            eta=t.FatJet_eta[idx]
            phi=t.FatJet_phi[idx]
            self.h1["fatjet_pt"].Fill(pt)
            self.h1["fatjet_eta"].Fill(eta)
            self.h1["fatjet_phi"].Fill(phi)
    
    def endjob(self):
        print("test_cleanedjets::endjob")
        c1 = ROOT.TCanvas("c1","test_cleanedjets",800,600)
        print("in endjob0")
        c1.Divide(2,2)
        c1.cd(1)
        s="fatjet_n"
        self.h1[s].Draw()
        c1.cd(2)
        s="fatjet_pt"
        self.h1[s].Draw()
        c1.cd(3)
        s="fatjet_eta"
        self.h1[s].Draw()
        c1.cd(4)
        s="fatjet_phi"
        self.h1[s].Draw()
        
        #  c1.Draw()  # Draw does not work here...
        c1.SaveAs("test_cleanedjets.pdf")
        #  for testing on mac
        # !open "test_cleanedjets.pdf"
        return

# %%
#  for testing this helper
def main():
    nanoDir="/Users/kunori/skdir/vkk/nanoAOD/"
    nanoFile=nanoDir+"signal_M1500_0_5_18.root"
    file = ROOT.TFile.Open(nanoFile)
    tree = file.Get("Events")

    t_myphoton=test_myphoton()
    t_cleanedjets=test_cleanedjets()
   
    count=0
    for it, t in enumerate(tree):
        if it >= 100:
            break
        count=count+1
    
        t_myphoton.analyze(t)
        t_cleanedjets.analyze(t)
        genIdx=getGenIndex(t)
        print("genIdx",genIdx)
        
        a=[]
        # a=["met","genPart","recoPhoton","recoPhoton_all","recoFatjet","recoFatjet_all"]
        # a=["met","genPart","recoPhoton","recoPhoton_all","recoFatjet"]
        if it in [0,1,20,26,40]:
            print_event(it, t,a)
            
    
    # end of job
    print("***",count,"Events Processed")
    t_myphoton.endjob()
    t_cleanedjets.endjob()
    
    dothis=[0,1,20,26,40]
        # a=[]
    # a=["met","genPart","recoPhoton","recoPhoton_all","recoFatjet","recoFatjet_all"]
    # a=["met","genPart","recoPhoton","recoPhoton_all","recoFatjet"]
    # print_event(it, t,a)

    print("end of def main...")
    return 0

if __name__ == '__main__':
    main()
    print("end of test job...")
# Out:
# iso_photon n= 1  idx [0]
# fatjet n= 1  idx [0]
# i 0 idx 0
# genIdx {'radion': 4, 'photon': 3, 'wp': 8, 'wm': 10, 'wp0': 11, 'wp1': 12, 'wm0': 13, 'wm1': 14}
#
# Event:  0
# === MET
#    GenMET pt      0.0     phi      2.8
#    MET    pt    100.8     phi      0.4
# === GenPart
#     stat      id  moth      pt     eta     phi    mass
#    4  62 9000025     2   497.0    1.45   -2.86   750.0
#    3  23      22     0   512.0    1.48    0.28     0.0
#    8  51      24     6   684.0    0.93   -2.94    79.8
#   10  52     -24     7   193.5    1.12   -0.02    79.8
#   11  23      -1     8   446.0    0.93   -2.86     0.0
#   12  23       2     8   243.5    0.92   -3.10     0.0
#   13  23       1    10    97.2    0.76    0.26     0.0
#   14  23      -2    10   103.5    1.34   -0.28     0.0
# === GenPart  (all)
#     stat      id  moth      pt     eta     phi    mass
#    0  21       2    -1     0.025088.00    0.00     0.0
#    1  21      -2    -1     0.0-22976.00    0.00     0.0
#    2  22 9000025     0   512.0    1.46   -2.86   750.0
#    3  23      22     0   512.0    1.48    0.28     0.0
#    4  62 9000025     2   497.0    1.45   -2.86   750.0
#    5   1      22     3   516.0    1.47    0.28     0.0
#    6  22      24     4   684.0    0.93   -2.94    79.8
#    7  22     -24     4   193.5    1.12   -0.02    79.8
#    8  51      24     6   684.0    0.93   -2.94    79.8
#    9   1      22     6     0.0    1.01    3.02     0.0
#   10  52     -24     7   193.5    1.12   -0.02    79.8
#   11  23      -1     8   446.0    0.93   -2.86     0.0
#   12  23       2     8   243.5    0.92   -3.10     0.0
#   13  23       1    10    97.2    0.76    0.26     0.0
#   14  23      -2    10   103.5    1.34   -0.28     0.0
#   15  71       2    11    33.9    0.95   -2.78     0.0
#   16  71      -1    11   143.5    0.90   -2.96     0.0
#   17  71       2    -1     0.6    2.95   -3.01     0.0
#   18  71      -1    -1     0.7   -3.55   -0.13     0.0
#   19  71       2    12   178.0    0.91   -3.09     0.0
#   20  71      21    12    24.9    1.03   -3.04     0.0
#   21  71      21    12    33.6    0.94   -2.84     0.0
#   22  71      21    11   232.0    0.95   -2.85     0.0
#   23   2     111    11    54.4    0.94   -2.84     0.0
#   24  71       1    13    55.0    0.77    0.27     0.0
#   25  71      21    13    25.9    0.76    0.28     0.0
#   26  71      21    14    24.8    1.30   -0.28     0.0
#   27  71      -2    14    70.5    1.36   -0.28     0.0
#   28   2     111    13    21.0    0.79    0.28     0.0
#   29   2     111    13    35.1    1.36   -0.27     0.0
#   30   2     111    11    17.2    0.97   -2.77     0.0
#   31   2     111    11    24.2    0.92   -2.96     0.0
#   32   2     111    13    18.7    1.35   -0.29     0.0
#   33   1      11    17     0.0   -1.94    2.52     0.0
#   34   1     -11    17     0.3   -1.93   -1.97     0.0
#   35   1      22    23    54.4    0.94   -2.84     0.0
#   36   1      22    28    17.1    0.79    0.28     0.0
#   37   1      22    29    31.5    1.36   -0.27     0.0
#   38   1      22    30    14.8    0.97   -2.77     0.0
#   39   1      22    31    21.8    0.91   -2.96     0.0
#   40   1      22    32    15.9    1.35   -0.29     0.0
# === Reco Photon
#           id      pt     eta     phi
#    0       1   471.7    1.46    0.28
# === Reco Photon  (all)
#           id      pt     eta     phi
#    0       1   471.7    1.46    0.28
#    1       0    71.2    1.36   -0.28
# === Reco Fatjet
#           id      pt     eta     phi sd mass
#    0       6   693.5    0.94   -2.96    81.0
# === Reco Fatjet  (all)
#           id      pt     eta     phi sd mass
#    0       6   693.5    0.94   -2.96    81.0
#    1       6   542.5    1.36    0.18   203.2
# iso_photon n= 0  idx []
# fatjet n= 2  idx [0, 1]
# i 0 idx 0
# i 1 idx 1
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
#
# Event:  1
# === MET
#    GenMET pt      0.0     phi      1.6
#    MET    pt    500.6     phi      2.8
# === GenPart
#     stat      id  moth      pt     eta     phi    mass
#    3  62 9000022     2    13.4    5.67    2.17  1504.0
#    4  22 9000025     3   552.0    1.62   -0.29   750.0
#    5   1      22     3   562.0    0.95    2.84     0.0
#    6  22      24     4   704.0    1.32   -0.40    79.8
#    7  22     -24     4   168.5    0.68    2.36    79.8
#    8  23      -1     6    15.8    0.90   -1.03     0.0
#    9  23       2     6   692.0    1.32   -0.39     0.0
#   10  23       1     7    13.9    1.45   -2.49     0.0
#   11  23      -2     7   167.0    0.54    2.27     0.0
# === GenPart  (all)
#     stat      id  moth      pt     eta     phi    mass
#    0  21       1    -1     0.024896.00    0.00     0.0
#    1  21      -1    -1     0.0-23040.00    0.00     0.0
#    2  22 9000022     0     0.024640.00    0.00  1504.0
#    3  62 9000022     2    13.4    5.67    2.17  1504.0
#    4  22 9000025     3   552.0    1.62   -0.29   750.0
#    5   1      22     3   562.0    0.95    2.84     0.0
#    6  22      24     4   704.0    1.32   -0.40    79.8
#    7  22     -24     4   168.5    0.68    2.36    79.8
#    8  23      -1     6    15.8    0.90   -1.03     0.0
#    9  23       2     6   692.0    1.32   -0.39     0.0
#   10  23       1     7    13.9    1.45   -2.49     0.0
#   11  23      -2     7   167.0    0.54    2.27     0.0
#   12  71      -1     8    11.2    0.87   -1.03     0.0
#   13  71      21    11    32.4    0.46    2.30     0.0
#   14  71      -2    11    23.0    0.42    2.59     0.0
#   15  71       2     9   461.0    1.32   -0.39     0.0
#   16  71      21     9   159.5    1.30   -0.40     0.0
#   17  71      21     9    31.2    1.32   -0.40     0.0
#   18  71      21     9    20.2    1.41   -0.33     0.0
#   19  71      21     9    17.3    1.42   -0.27     0.0
#   20   2     111     9    22.4    1.31   -0.39     0.0
#   21  71       1    10     9.3    1.45   -2.49     0.0
#   22  71      21    11    33.1    0.80    2.09     0.0
#   23   2     111    11    11.3    0.77    2.09     0.0
#   24   2     111     9    24.4    1.35   -0.38     0.0
#   25   2     111     9    33.2    1.31   -0.41     0.0
#   26   1      22    20    13.7    1.30   -0.39     0.0
#   27   1      22    23    11.2    0.77    2.09     0.0
#   28   1      22    24    23.2    1.35   -0.38     0.0
#   29   1      22    25    17.0    1.31   -0.41     0.0
#   30   1      22    25    16.2    1.30   -0.40     0.0
# === Reco Photon  (all)
#           id      pt     eta     phi
#    0       0    20.5    0.41    2.46
#    1       0    21.0    0.68    2.16
# === Reco Fatjet
#           id      pt     eta     phi sd mass
#    0       6   673.5    1.32   -0.41     0.7
#    1       6   171.6    0.58    2.31    -1.0
# === Reco Fatjet  (all)
#           id      pt     eta     phi sd mass
#    0       6   673.5    1.32   -0.41     0.7
#    1       6   171.6    0.58    2.31    -1.0
# === Reco Electron  (all)
#           pt     eta     phi
#    0     8.8    0.68    1.97
# iso_photon n= 1  idx [1]
# fatjet n= 2  idx [0, 2]
# i 0 idx 0
# i 1 idx 2
# genIdx {'akk': 5, 'radion': 6, 'photon': 7, 'wp': 10, 'wm': 12, 'wp0': 13, 'wp1': 14, 'wm0': 19, 'wm1': 20}
# iso_photon n= 1  idx [0]
# fatjet n= 2  idx [0, 2]
# i 0 idx 0
# i 1 idx 2
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 13, 'wm1': 14}
# iso_photon n= 0  idx []
# fatjet n= 2  idx [0, 1]
# i 0 idx 0
# i 1 idx 1
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 10, 'wm': 8, 'wp0': 11, 'wp1': 12, 'wm0': 16, 'wm1': 17}
# iso_photon n= 2  idx [0, 1]
# fatjet n= 1  idx [1]
# i 0 idx 1
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 14, 'wm1': 15}
# iso_photon n= 1  idx [0]
# fatjet n= 2  idx [0, 2]
# i 0 idx 0
# i 1 idx 2
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
# iso_photon n= 1  idx [0]
# fatjet n= 2  idx [0, 2]
# i 0 idx 0
# i 1 idx 2
# genIdx {'radion': 4, 'photon': 3, 'wp': 14, 'wm': 16, 'wp0': 17, 'wp1': 18, 'wm0': 19, 'wm1': 20}
# iso_photon n= 1  idx [0]
# fatjet n= 1  idx [1]
# i 0 idx 1
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 10, 'wm': 8, 'wp0': 11, 'wp1': 12, 'wm0': 13, 'wm1': 14}
# iso_photon n= 1  idx [0]
# fatjet n= 2  idx [1, 2]
# i 0 idx 1
# i 1 idx 2
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
# iso_photon n= 0  idx []
# fatjet n= 3  idx [0, 1, 2]
# i 0 idx 0
# i 1 idx 1
# i 2 idx 2
# genIdx {'akk': 3, 'radion': 6, 'photon': 5, 'wp': 10, 'wm': 11, 'wp0': 12, 'wp1': 13, 'wm0': 14, 'wm1': 15}
# iso_photon n= 0  idx []
# fatjet n= 2  idx [0, 1]
# i 0 idx 0
# i 1 idx 1
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 13, 'wm1': 14}
# iso_photon n= 0  idx []
# fatjet n= 2  idx [0, 1]
# i 0 idx 0
# i 1 idx 1
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 13, 'wm1': 14}
# iso_photon n= 1  idx [0]
# fatjet n= 2  idx [1, 2]
# i 0 idx 1
# i 1 idx 2
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
# iso_photon n= 1  idx [0]
# fatjet n= 1  idx [1]
# i 0 idx 1
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
# iso_photon n= 1  idx [0]
# fatjet n= 2  idx [0, 1]
# i 0 idx 0
# i 1 idx 1
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 10, 'wm': 9, 'wp0': 11, 'wp1': 16, 'wm0': 13, 'wm1': 14}
# iso_photon n= 1  idx [0]
# fatjet n= 2  idx [0, 2]
# i 0 idx 0
# i 1 idx 2
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
# iso_photon n= 1  idx [0]
# fatjet n= 2  idx [0, 2]
# i 0 idx 0
# i 1 idx 2
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
# iso_photon n= 1  idx [0]
# fatjet n= 2  idx [1, 2]
# i 0 idx 1
# i 1 idx 2
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 10, 'wm': 8, 'wp0': 11, 'wp1': 12, 'wm0': 13, 'wm1': 14}
# iso_photon n= 1  idx [0]
# fatjet n= 1  idx [1]
# i 0 idx 1
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 10, 'wm': 8, 'wp0': 11, 'wp1': 12, 'wm0': 13, 'wm1': 14}
# iso_photon n= 0  idx []
# fatjet n= 3  idx [0, 1, 2]
# i 0 idx 0
# i 1 idx 1
# i 2 idx 2
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
#
# Event:  20
# === MET
#    GenMET pt     30.4     phi      2.0
#    MET    pt     65.7     phi      2.9
# === GenPart
#     stat      id  moth      pt     eta     phi    mass
#    3  62 9000022     2    24.7    1.17    0.15  1496.0
#    4  22 9000025     3   393.0   -0.88    0.17   750.0
#    5   1      22     3   368.0    0.99   -2.97     0.0
#    6  22      24     4   277.0   -0.59    2.07    79.8
#    7  22     -24     4   548.0   -0.38   -0.33    79.8
#    8  23      -3     6   109.8   -0.23    2.11     0.0
#    9  23       4     6   168.0   -0.80    2.04     0.0
#   10  23       1     7   215.0   -0.30   -0.49     0.0
#   11  23      -4     7   338.0   -0.43   -0.22     0.0
# === GenPart  (all)
#     stat      id  moth      pt     eta     phi    mass
#    0  21      -2    -1     0.023488.00    0.00     0.0
#    1  21       2    -1     0.0-23488.00    0.00     0.0
#    2  22 9000022     0     0.0   34.62    0.00  1496.0
#    3  62 9000022     2    24.7    1.17    0.15  1496.0
#    4  22 9000025     3   393.0   -0.88    0.17   750.0
#    5   1      22     3   368.0    0.99   -2.97     0.0
#    6  22      24     4   277.0   -0.59    2.07    79.8
#    7  22     -24     4   548.0   -0.38   -0.33    79.8
#    8  23      -3     6   109.8   -0.23    2.11     0.0
#    9  23       4     6   168.0   -0.80    2.04     0.0
#   10  23       1     7   215.0   -0.30   -0.49     0.0
#   11  23      -4     7   338.0   -0.43   -0.22     0.0
#   12  71       1    10   123.8   -0.33   -0.46     0.0
#   13  71      21    10    28.9   -0.26   -0.35     0.0
#   14  71      21    10    30.6   -0.21   -0.35     0.0
#   15  71       2    10    38.9   -0.47   -0.56     0.0
#   16  71      21    11    52.4   -0.44   -0.23     0.0
#   17  71      21    11    18.1   -0.46   -0.19     0.0
#   18  71      -4    11   190.0   -0.42   -0.22     0.0
#   19   2     221    10    27.2   -0.46   -0.22     0.5
#   20   2    -421    10   156.5   -0.42   -0.22     0.0
#   21  71       4     9   169.5   -0.80    2.05     0.0
#   22  71      -3     8   100.2   -0.23    2.12     0.0
#   23   2     413     8   106.0   -0.80    2.05     2.0
#   24  71       3    -1     0.6    6.67    1.24     0.0
#   25  71      -3    -1     3.0    4.59   -2.80     0.0
#   26   2     111    10    14.3   -0.48   -0.55     0.0
#   27   1      22    19    25.2   -0.47   -0.23     0.0
#   28   2     411    23    97.2   -0.80    2.05     0.0
#   29   1      11    24     0.2    6.34    2.92     0.0
#   30   1     -11    24     0.3    6.39    2.83     0.0
#   31   1      22    26    11.0   -0.48   -0.55     0.0
#   32   1     -13    28    16.4   -0.80    2.05     0.0
#   33   1      14    28    30.4   -0.79    2.02     0.0
# === Reco Photon  (all)
#           id      pt     eta     phi
#    0       0   384.2    1.00   -2.97
# === Reco Fatjet
#           id      pt     eta     phi sd mass
#    0       6   540.0   -0.37   -0.32    63.9
#    1       0   372.2    1.01   -2.96     0.0
#    2       6   213.2   -0.55    2.07    62.8
# === Reco Fatjet  (all)
#           id      pt     eta     phi sd mass
#    0       6   540.0   -0.37   -0.32    63.9
#    1       0   372.2    1.01   -2.96     0.0
#    2       6   213.2   -0.55    2.07    62.8
# === Reco Electron  (all)
#           pt     eta     phi
#    0    39.6   -0.47   -0.22
# === Reco Muon  (all)
#           pt     eta     phi
#    0    16.2   -0.80    2.06
# === Reco Tau ===  (all)
#           pt     eta     phi
#    0    45.9   -0.79    2.04
# iso_photon n= 0  idx []
# fatjet n= 3  idx [0, 1, 2]
# i 0 idx 0
# i 1 idx 1
# i 2 idx 2
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
# iso_photon n= 1  idx [0]
# fatjet n= 2  idx [0, 2]
# i 0 idx 0
# i 1 idx 2
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
# iso_photon n= 1  idx [0]
# fatjet n= 1  idx [1]
# i 0 idx 1
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 13, 'wm': 11, 'wp0': 14, 'wp1': 15, 'wm0': 16, 'wm1': 17}
# iso_photon n= 1  idx [0]
# fatjet n= 1  idx [0]
# i 0 idx 0
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
# iso_photon n= 0  idx []
# fatjet n= 3  idx [0, 1, 2]
# i 0 idx 0
# i 1 idx 1
# i 2 idx 2
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
# iso_photon n= 0  idx []
# fatjet n= 3  idx [0, 1, 2]
# i 0 idx 0
# i 1 idx 1
# i 2 idx 2
# genIdx {'akk': 4, 'radion': 5, 'photon': 6, 'wp': 14, 'wm': 12, 'wp0': 15, 'wp1': 16, 'wm0': 17, 'wm1': 18}
#
# Event:  26
# === MET
#    GenMET pt      2.3     phi     -1.1
#    MET    pt     62.8     phi     -1.6
# === GenPart
#     stat      id  moth      pt     eta     phi    mass
#    4  62 9000022     2   170.5    0.78    2.20  1500.0
#    5  22 9000025     4   247.0   -1.34    3.01   750.0
#    6   1      22     4   178.5    1.91    0.62     0.0
#   14  52      24     9   342.0   -0.84   -1.80    79.8
#   12  51     -24    11   402.0   -0.29    2.00    79.8
#   15  23      -1    14   273.0   -0.74   -1.72     0.0
#   16  23       2    14    73.5   -1.14   -2.12     0.0
#   17  23       3    12   240.0   -0.40    1.88     0.0
#   18  23      -4    12   166.0   -0.12    2.16     0.0
# === GenPart  (all)
#     stat      id  moth      pt     eta     phi    mass
#    0  21       2    -1     0.023552.00    0.00     0.0
#    1  21      -2    -1     0.0-23488.00    0.00     0.0
#    2  22 9000022     0     0.0   35.75   -1.57  1500.0
#    3  31      -4    -1     0.022848.00    0.00     0.0
#    4  62 9000022     2   170.5    0.78    2.20  1500.0
#    5  22 9000025     4   247.0   -1.34    3.01   750.0
#    6   1      22     4   178.5    1.91    0.62     0.0
#    7  22      24     5   342.0   -0.84   -1.80    79.8
#    8  22     -24     5   402.0   -0.29    2.00    79.8
#    9  51      24     7   342.0   -0.84   -1.80    79.8
#   10   1      22     7     0.0   -1.50   -2.56     0.0
#   11  52     -24     8   402.0   -0.29    2.00    79.8
#   12  51     -24    11   402.0   -0.29    2.00    79.8
#   13   1      22    11     0.0    0.55   -2.55     0.0
#   14  52      24     9   342.0   -0.84   -1.80    79.8
#   15  23      -1    14   273.0   -0.74   -1.72     0.0
#   16  23       2    14    73.5   -1.14   -2.12     0.0
#   17  23       3    12   240.0   -0.40    1.88     0.0
#   18  23      -4    12   166.0   -0.12    2.16     0.0
#   19  73       5    -1    21.1    0.26   -1.36     0.0
#   20  73       5    19    22.2    0.25   -1.38     0.0
#   21   2     413    -1     0.4    3.71    2.95     2.0
#   22   2    -411    -1     1.2    3.02    0.30     0.0
#   23   2     413    -1     2.8   -0.89   -0.46     2.0
#   24  71      21    15    67.0   -0.76   -1.72     0.0
#   25  71      -1    15   195.5   -0.74   -1.72     0.0
#   26   2     111    15    14.5   -0.74   -1.74     0.0
#   27  71       2    16    18.4   -1.10   -2.13     0.0
#   28  71      21    16    34.8   -1.15   -2.12     0.0
#   29  71       2    -1     1.3    1.53   -0.49     0.0
#   30  71      -2    -1     0.4    7.80    2.30     0.0
#   31   2     423    -1     1.8    1.36   -2.93     2.0
#   32  71       5    20    22.2    0.25   -1.38     0.0
#   33   2    -511     3    19.4    0.24   -1.36     5.3
#   34   2    -421     3     3.9   -1.05    1.14     0.0
#   35  71       1     3     0.8    1.98   -0.57     0.0
#   36  71      -4     3     3.6    3.63    0.22     0.0
#   37   2    -413     3     3.0    3.73    0.12     2.0
#   38  71      -5    -1    98.0   -0.09   -0.85     0.0
#   39   2   -5214    38    96.5   -0.09   -0.85     5.8
#   40  71       3    17   196.5   -0.40    1.88     0.0
#   41  71      21    18    38.9   -0.43    1.92     0.0
#   42  71      -4    18   163.0   -0.11    2.16     0.0
#   43   2    -431    18   143.5   -0.11    2.15     2.0
#   44   2     111    18    17.1   -0.41    1.88     0.0
#   45   2     421    21     0.3    3.76    2.91     0.0
#   46   2     421    23     2.5   -0.89   -0.46     0.0
#   47   1      22    26    10.2   -0.74   -1.73     0.0
#   48   2     421    31     1.7    1.35   -2.91     0.0
#   49   2     111    31     0.1    1.47    3.07     0.0
#   50   2     411    33     6.0    0.28   -1.36     0.0
#   51   2    -421    37     2.8    3.73    0.11     0.0
#   52   2   -5122    39    93.0   -0.09   -0.86     5.6
#   53   1      11    29     0.0    2.91    0.84     0.0
#   54   1     -11    29     0.2    2.91    0.86     0.0
#   55   1      11     3     0.2    1.21   -1.10     0.0
#   56   1     -11     3     0.1    1.21   -1.10     0.0
#   57   1      22    44    11.0   -0.40    1.88     0.0
#   58   1      11    49     0.0    1.83    2.59     0.0
#   59   1     -11    49     0.1    1.78    2.77     0.0
#   60   1     -11    50     1.2   -0.17   -1.31     0.0
#   61   1      12    50     0.7    0.85   -1.44     0.0
#   62   2    -411    52    34.0   -0.09   -0.85     0.0
#   63   2     111    43    20.5   -0.13    2.16     0.0
#   64   1      11    62     6.0   -0.12   -0.84     0.0
#   65   1     -12    62     1.6    0.08   -1.01     0.0
#   66   1      22    63    16.9   -0.13    2.16     0.0
# === Reco Photon  (all)
#           id      pt     eta     phi
#    0       0   209.6   -0.40    1.89
#    1       1   180.1    1.91    0.62
# === Reco Fatjet
#           id      pt     eta     phi sd mass
#    0       6   451.2   -0.28    2.00    89.3
#    1       6   351.0   -0.83   -1.78    89.5
#    2       0   200.2    1.90    0.63    -1.0
# === Reco Fatjet  (all)
#           id      pt     eta     phi sd mass
#    0       6   451.2   -0.28    2.00    89.3
#    1       6   351.0   -0.83   -1.78    89.5
#    2       0   200.2    1.90    0.63    -1.0
# === Reco Electron  (all)
#           pt     eta     phi
#    0   179.9    1.91    0.62
#    1    14.6   -0.12   -0.85
# === Reco Tau ===  (all)
#           pt     eta     phi
#    0    21.8   -0.11   -0.87
# iso_photon n= 1  idx [0]
# fatjet n= 1  idx [1]
# i 0 idx 1
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
# iso_photon n= 1  idx [0]
# fatjet n= 1  idx [0]
# i 0 idx 0
# genIdx {'akk': 5, 'radion': 6, 'photon': 7, 'wp': 8, 'wm': 9, 'wp0': 10, 'wp1': 11, 'wm0': 12, 'wm1': 13}
# iso_photon n= 1  idx [0]
# fatjet n= 2  idx [0, 1]
# i 0 idx 0
# i 1 idx 1
# genIdx {'akk': 4, 'radion': 5, 'photon': 6, 'wp': 9, 'wm': 11, 'wp0': 12, 'wp1': 13, 'wm0': 14, 'wm1': 15}
# iso_photon n= 1  idx [0]
# fatjet n= 1  idx [1]
# i 0 idx 1
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
# iso_photon n= 1  idx [0]
# fatjet n= 1  idx [1]
# i 0 idx 1
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
# iso_photon n= 0  idx []
# fatjet n= 2  idx [0, 1]
# i 0 idx 0
# i 1 idx 1
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
# iso_photon n= 1  idx [0]
# fatjet n= 1  idx [1]
# i 0 idx 1
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 11, 'wm': 13, 'wp0': 14, 'wp1': 15, 'wm0': 16, 'wm1': 17}
# iso_photon n= 1  idx [0]
# fatjet n= 1  idx [1]
# i 0 idx 1
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 10, 'wm': 8, 'wp0': 11, 'wp1': 12, 'wm0': 13, 'wm1': 14}
# iso_photon n= 1  idx [0]
# fatjet n= 2  idx [1, 2]
# i 0 idx 1
# i 1 idx 2
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 10, 'wm': 8, 'wp0': 11, 'wp1': 12, 'wm0': 13, 'wm1': 14}
# iso_photon n= 1  idx [0]
# fatjet n= 1  idx [0]
# i 0 idx 0
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 8, 'wm': 10, 'wp0': 11, 'wp1': 12, 'wm0': 13, 'wm1': 14}
# iso_photon n= 1  idx [0]
# fatjet n= 1  idx [1]
# i 0 idx 1
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
# iso_photon n= 1  idx [0]
# fatjet n= 2  idx [0, 1]
# i 0 idx 0
# i 1 idx 1
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 8, 'wm': 10, 'wp0': 11, 'wp1': 12, 'wm0': 13, 'wm1': 14}
# iso_photon n= 1  idx [0]
# fatjet n= 3  idx [1, 2, 3]
# i 0 idx 1
# i 1 idx 2
# i 2 idx 3
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
# iso_photon n= 1  idx [0]
# fatjet n= 1  idx [0]
# i 0 idx 0
# genIdx {'akk': 3, 'radion': 5, 'photon': 6, 'wp': 7, 'wm': 8, 'wp0': 9, 'wp1': 10, 'wm0': 11, 'wm1': 12}
#
# Event:  40
# === MET
#    GenMET pt    178.0     phi      1.7
#    MET    pt    169.5     phi      1.6
# === GenPart
#     stat      id  moth      pt     eta     phi    mass
#    3  62 9000022     2    17.8    5.27   -1.94  1500.0
#    5  22 9000025     3   562.0    1.41   -0.15   748.0
#    6   1      22     3   566.0    0.96    3.02     0.0
#    7  22      24     5   236.5    0.75    1.71    79.8
#    8  22     -24     5   668.0    1.10   -0.49    79.8
#    9   2     -15     7    71.5    0.23    1.60     0.0
#   10   1      16     7   165.5    0.93    1.75     0.0
#   11  23       1     8   357.0    1.02   -0.57     0.0
#   12  23      -2     8   313.0    1.19   -0.41     0.0
# === GenPart  (all)
#     stat      id  moth      pt     eta     phi    mass
#    0  21       2    -1     0.024768.00    0.00     0.0
#    1  21      -2    -1     0.0-23040.00    0.00     0.0
#    2  22 9000022     0     0.0   39.38    1.57  1500.0
#    3  62 9000022     2    17.8    5.27   -1.94  1500.0
#    4   1      22    -1     0.2    1.98   -1.77     0.0
#    5  22 9000025     3   562.0    1.41   -0.15   748.0
#    6   1      22     3   566.0    0.96    3.02     0.0
#    7  22      24     5   236.5    0.75    1.71    79.8
#    8  22     -24     5   668.0    1.10   -0.49    79.8
#    9   2     -15     7    71.5    0.23    1.60     0.0
#   10   1      16     7   165.5    0.93    1.75     0.0
#   11  23       1     8   357.0    1.02   -0.57     0.0
#   12  23      -2     8   313.0    1.19   -0.41     0.0
#   13  71       1    11   301.0    1.03   -0.55     0.0
#   14  71      21    11    39.1    1.04   -0.60     0.0
#   15  71      21    11    19.2    1.08   -0.49     0.0
#   16  71      21    11    17.4    1.14   -0.42     0.0
#   17  71      -2    12   274.0    1.19   -0.41     0.0
#   18   2     111    11    12.4    1.20   -0.37     0.0
#   19   2     111    11    58.8    1.20   -0.41     0.0
#   20  71       1    -1    16.3    2.85    0.78     0.0
#   21  71       2    -1     0.5   -6.53   -0.09     0.0
#   22  71      -2    -1     2.0    2.75    0.55     0.0
#   23   2     111    11    55.6    1.18   -0.40     0.0
#   24   1     -16     9    12.7    0.25    1.61     0.0
#   25   2     111     9    10.3    0.25    1.59     0.0
#   26   2     111     9    17.9    0.21    1.59     0.0
#   27   1     211     9    12.6    0.20    1.59     0.0
#   28   1     211     9    15.2    0.24    1.60     0.0
#   29   1    -211     9     2.8    0.21    1.61     0.0
#   30   1      22    18    11.8    1.20   -0.37     0.0
#   31   2     111    11    46.6    1.18   -0.41     0.0
#   32   1      22    19    15.8    1.20   -0.40     0.0
#   33   1      22    19    43.0    1.20   -0.41     0.0
#   34   1      22    23    54.1    1.18   -0.40     0.0
#   35   1      11    21     0.0   -0.25    0.91     0.0
#   36   1     -11    21     0.0   -0.34    1.03     0.0
#   37   1      22    25     9.8    0.25    1.59     0.0
#   38   1      22    25     0.5    0.29    1.55     0.0
#   39   1      22    26    15.2    0.21    1.59     0.0
#   40   1      22    26     2.6    0.21    1.57     0.0
#   41   1      22    31    29.9    1.18   -0.41     0.0
#   42   1      22    31    16.8    1.18   -0.41     0.0
# === Reco Photon
#           id      pt     eta     phi
#    0       1   572.1    0.96    3.03
# === Reco Photon  (all)
#           id      pt     eta     phi
#    0       1   572.1    0.96    3.03
#    1       0   262.0    1.19   -0.40
# === Reco Fatjet
#           id      pt     eta     phi sd mass
#    0       6   658.0    1.10   -0.50    77.1
# === Reco Fatjet  (all)
#           id      pt     eta     phi sd mass
#    0       6   658.0    1.10   -0.50    77.1
#    1       0   625.5    0.95    3.03    -0.0
# === Reco Tau ===  (all)
#           pt     eta     phi
#    0    58.7    0.22    1.60
# iso_photon n= 1  idx [0]
# fatjet n= 1  idx [0]
# i 0 idx 0
# genIdx {'akk': 5, 'radion': 8, 'photon': 9, 'wp': 10, 'wm': 11, 'wp0': 12, 'wp1': 13, 'wm0': 14, 'wm1': 15}
# iso_photon n= 0  idx []
# fatjet n= 3  idx [0, 1, 2]
# i 0 idx 0
# i 1 idx 1
# i 2 idx 2
# genIdx {'akk': 3, 'radion': 8, 'photon': 5, 'wp': 9, 'wm': 10, 'wp0': 11, 'wp1': 12, 'wm0': 13, 'wm1': 14}
# iso_photon n= 1  idx [0]
# fatjet n= 2  idx [1, 2]
# i 0 idx 1
# i 1 idx 2
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 8, 'wm': 10, 'wp0': 11, 'wp1': 12, 'wm0': 13, 'wm1': 14}
# iso_photon n= 1  idx [0]
# fatjet n= 2  idx [0, 2]
# i 0 idx 0
# i 1 idx 2
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 8, 'wm': 10, 'wp0': 11, 'wp1': 12, 'wm0': 14, 'wm1': 15}
# iso_photon n= 1  idx [0]
# fatjet n= 1  idx [1]
# i 0 idx 1
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 10, 'wm': 8, 'wp0': 11, 'wp1': 12, 'wm0': 13, 'wm1': 14}
# iso_photon n= 1  idx [0]
# fatjet n= 2  idx [1, 2]
# i 0 idx 1
# i 1 idx 2
# genIdx {'akk': 3, 'radion': 5, 'photon': 6, 'wp': 7, 'wm': 8, 'wp0': 9, 'wp1': 10, 'wm0': 11, 'wm1': 12}
# iso_photon n= 0  idx []
# fatjet n= 2  idx [0, 1]
# i 0 idx 0
# i 1 idx 1
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 10, 'wm': 8, 'wp0': 11, 'wp1': 12, 'wm0': 13, 'wm1': 14}
# iso_photon n= 1  idx [0]
# fatjet n= 0  idx []
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 8, 'wm': 10, 'wp0': 11, 'wp1': 12, 'wm0': 13, 'wm1': 14}
# iso_photon n= 1  idx [0]
# fatjet n= 1  idx [0]
# i 0 idx 0
# genIdx {'radion': 4, 'photon': 3, 'wp': 10, 'wm': 8, 'wp0': 11, 'wp1': 12, 'wm0': 13, 'wm1': 14}
# iso_photon n= 2  idx [0, 2]
# fatjet n= 0  idx []
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 13, 'wm1': 14}
# iso_photon n= 1  idx [0]
# fatjet n= 2  idx [0, 2]
# i 0 idx 0
# i 1 idx 2
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 8, 'wm': 10, 'wp0': 11, 'wp1': 12, 'wm0': 13, 'wm1': 14}
# iso_photon n= 0  idx []
# fatjet n= 3  idx [0, 1, 2]
# i 0 idx 0
# i 1 idx 1
# i 2 idx 2
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
# iso_photon n= 1  idx [0]
# fatjet n= 0  idx []
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
# iso_photon n= 1  idx [0]
# fatjet n= 2  idx [0, 2]
# i 0 idx 0
# i 1 idx 2
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
# iso_photon n= 1  idx [0]
# fatjet n= 2  idx [1, 2]
# i 0 idx 1
# i 1 idx 2
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 8, 'wm': 10, 'wp0': 11, 'wp1': 12, 'wm0': 16, 'wm1': 17}
# iso_photon n= 2  idx [0, 1]
# fatjet n= 1  idx [2]
# i 0 idx 2
# genIdx {'akk': 3, 'radion': 5, 'photon': 6, 'wp': 7, 'wm': 8, 'wp0': 9, 'wp1': 10, 'wm0': 14, 'wm1': 15}
# iso_photon n= 1  idx [0]
# fatjet n= 1  idx [1]
# i 0 idx 1
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 13, 'wm1': 14}
# iso_photon n= 1  idx [1]
# fatjet n= 3  idx [0, 1, 2]
# i 0 idx 0
# i 1 idx 1
# i 2 idx 2
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
# iso_photon n= 1  idx [0]
# fatjet n= 2  idx [0, 2]
# i 0 idx 0
# i 1 idx 2
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 14, 'wm': 16, 'wp0': 17, 'wp1': 18, 'wm0': 24, 'wm1': 25}
# iso_photon n= 0  idx []
# fatjet n= 2  idx [0, 1]
# i 0 idx 0
# i 1 idx 1
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 8, 'wm': 10, 'wp0': 11, 'wp1': 12, 'wm0': 13, 'wm1': 14}
# iso_photon n= 1  idx [0]
# fatjet n= 2  idx [0, 1]
# i 0 idx 0
# i 1 idx 1
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 14, 'wm': 16, 'wp0': 17, 'wp1': 18, 'wm0': 19, 'wm1': 20}
# iso_photon n= 1  idx [0]
# fatjet n= 2  idx [0, 2]
# i 0 idx 0
# i 1 idx 2
# genIdx {'akk': 4, 'radion': 6, 'photon': 7, 'wp': 8, 'wm': 9, 'wp0': 10, 'wp1': 11, 'wm0': 12, 'wm1': 13}
# iso_photon n= 1  idx [0]
# fatjet n= 0  idx []
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 13, 'wm1': 14}
# iso_photon n= 1  idx [0]
# fatjet n= 2  idx [1, 2]
# i 0 idx 1
# i 1 idx 2
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
# iso_photon n= 1  idx [0]
# fatjet n= 2  idx [1, 2]
# i 0 idx 1
# i 1 idx 2
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 8, 'wm': 10, 'wp0': 11, 'wp1': 12, 'wm0': 13, 'wm1': 14}
# iso_photon n= 0  idx []
# fatjet n= 2  idx [0, 1]
# i 0 idx 0
# i 1 idx 1
# genIdx {'akk': 4, 'radion': 6, 'photon': 7, 'wp': 12, 'wm': 10, 'wp0': 13, 'wp1': 14, 'wm0': 15, 'wm1': 16}
# iso_photon n= 1  idx [3]
# fatjet n= 1  idx [1]
# i 0 idx 1
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 13, 'wm': 11, 'wp0': 14, 'wp1': 15, 'wm0': 16, 'wm1': 17}
# iso_photon n= 1  idx [0]
# fatjet n= 2  idx [0, 2]
# i 0 idx 0
# i 1 idx 2
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
# iso_photon n= 1  idx [0]
# fatjet n= 3  idx [1, 2, 3]
# i 0 idx 1
# i 1 idx 2
# i 2 idx 3
# genIdx {'radion': 4, 'photon': 3, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
# iso_photon n= 1  idx [0]
# fatjet n= 2  idx [0, 2]
# i 0 idx 0
# i 1 idx 2
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
# iso_photon n= 1  idx [1]
# fatjet n= 2  idx [0, 1]
# i 0 idx 0
# i 1 idx 1
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 11, 'wm1': 12}
# iso_photon n= 1  idx [0]
# fatjet n= 2  idx [1, 2]
# i 0 idx 1
# i 1 idx 2
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
# iso_photon n= 1  idx [0]
# fatjet n= 1  idx [0]
# i 0 idx 0
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
# iso_photon n= 1  idx [0]
# fatjet n= 1  idx [0]
# i 0 idx 0
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 13, 'wm': 11, 'wp0': 14, 'wp1': 15, 'wm0': 16, 'wm1': 17}
# iso_photon n= 0  idx []
# fatjet n= 2  idx [0, 1]
# i 0 idx 0
# i 1 idx 1
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 8, 'wm': 10, 'wp0': 11, 'wp1': 12, 'wm0': 13, 'wm1': 14}
# iso_photon n= 1  idx [0]
# fatjet n= 0  idx []
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 8, 'wm': 10, 'wp0': 11, 'wp1': 12, 'wm0': 13, 'wm1': 14}
# iso_photon n= 0  idx []
# fatjet n= 2  idx [0, 1]
# i 0 idx 0
# i 1 idx 1
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 13, 'wm1': 14}
# iso_photon n= 1  idx [0]
# fatjet n= 1  idx [0]
# i 0 idx 0
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 10, 'wm': 8, 'wp0': 11, 'wp1': 12, 'wm0': 13, 'wm1': 14}
# iso_photon n= 1  idx [0]
# fatjet n= 2  idx [1, 2]
# i 0 idx 1
# i 1 idx 2
# genIdx {'akk': 4, 'radion': 5, 'photon': 6, 'wp': 14, 'wm': 12, 'wp0': 15, 'wp1': 16, 'wm0': 20, 'wm1': 21}
# iso_photon n= 0  idx []
# fatjet n= 4  idx [0, 1, 2, 3]
# i 0 idx 0
# i 1 idx 1
# i 2 idx 2
# i 3 idx 3
# genIdx {'akk': 3, 'radion': 6, 'photon': 5, 'wp': 7, 'wm': 8, 'wp0': 9, 'wp1': 10, 'wm0': 11, 'wm1': 12}
# iso_photon n= 1  idx [0]
# fatjet n= 2  idx [1, 2]
# i 0 idx 1
# i 1 idx 2
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
# iso_photon n= 1  idx [0]
# fatjet n= 1  idx [1]
# i 0 idx 1
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 10, 'wm': 8, 'wp0': 11, 'wp1': 12, 'wm0': 13, 'wm1': 14}
# iso_photon n= 0  idx []
# fatjet n= 2  idx [0, 1]
# i 0 idx 0
# i 1 idx 1
# genIdx {'akk': 3, 'radion': 6, 'photon': 5, 'wp': 7, 'wm': 8, 'wp0': 9, 'wp1': 10, 'wm0': 11, 'wm1': 12}
# iso_photon n= 1  idx [0]
# fatjet n= 2  idx [1, 2]
# i 0 idx 1
# i 1 idx 2
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
# iso_photon n= 2  idx [0, 2]
# fatjet n= 1  idx [1]
# i 0 idx 1
# genIdx {'akk': 4, 'radion': 5, 'photon': 6, 'wp': 7, 'wm': 8, 'wp0': 9, 'wp1': 10, 'wm0': 11, 'wm1': 12}
# iso_photon n= 1  idx [0]
# fatjet n= 1  idx [1]
# i 0 idx 1
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
# iso_photon n= 0  idx []
# fatjet n= 2  idx [0, 1]
# i 0 idx 0
# i 1 idx 1
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 10, 'wm': 8, 'wp0': 11, 'wp1': 12, 'wm0': 16, 'wm1': 17}
# iso_photon n= 1  idx [0]
# fatjet n= 3  idx [1, 2, 3]
# i 0 idx 1
# i 1 idx 2
# i 2 idx 3
# genIdx {'akk': 4, 'radion': 7, 'photon': 8, 'wp': 9, 'wm': 10, 'wp0': 11, 'wp1': 12, 'wm0': 13, 'wm1': 14}
# iso_photon n= 1  idx [0]
# fatjet n= 1  idx [0]
# i 0 idx 0
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
# iso_photon n= 1  idx [0]
# fatjet n= 1  idx [0]
# i 0 idx 0
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
# iso_photon n= 1  idx [0]
# fatjet n= 1  idx [1]
# i 0 idx 1
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 11, 'wm': 13, 'wp0': 14, 'wp1': 15, 'wm0': 19, 'wm1': 20}
# iso_photon n= 1  idx [0]
# fatjet n= 1  idx [0]
# i 0 idx 0
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
# iso_photon n= 1  idx [0]
# fatjet n= 2  idx [1, 2]
# i 0 idx 1
# i 1 idx 2
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 10, 'wm': 8, 'wp0': 11, 'wp1': 12, 'wm0': 13, 'wm1': 14}
# iso_photon n= 1  idx [0]
# fatjet n= 1  idx [0]
# i 0 idx 0
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 8, 'wm': 10, 'wp0': 11, 'wp1': 12, 'wm0': 13, 'wm1': 14}
# iso_photon n= 1  idx [0]
# fatjet n= 2  idx [0, 2]
# i 0 idx 0
# i 1 idx 2
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
# iso_photon n= 2  idx [0, 1]
# fatjet n= 1  idx [0]
# i 0 idx 0
# genIdx {'akk': 3, 'radion': 5, 'photon': 6, 'wp': 15, 'wm': 17, 'wp0': 18, 'wp1': 19, 'wm0': 23, 'wm1': 24}
# iso_photon n= 1  idx [0]
# fatjet n= 2  idx [1, 2]
# i 0 idx 1
# i 1 idx 2
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
# iso_photon n= 0  idx []
# fatjet n= 2  idx [0, 1]
# i 0 idx 0
# i 1 idx 1
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 10, 'wm1': 11}
# iso_photon n= 0  idx []
# fatjet n= 0  idx []
# genIdx {'akk': 3, 'radion': 4, 'photon': 5, 'wp': 6, 'wm': 7, 'wp0': 8, 'wp1': 9, 'wm0': 13, 'wm1': 14}
# *** 100 Events Processed
# test_myphoton::endjob
# in endjob0
# in endjob5
# test_cleanedjets::endjob
# in endjob0
# end of def main...
# end of test job...
# Warning in <TClass::Init>: no dictionary for class edm::Hash<1> is available
# Warning in <TClass::Init>: no dictionary for class edm::ProcessHistory is available
# Warning in <TClass::Init>: no dictionary for class edm::ProcessConfiguration is available
# Warning in <TClass::Init>: no dictionary for class edm::ParameterSetBlob is available
# Warning in <TClass::Init>: no dictionary for class pair<edm::Hash<1>,edm::ParameterSetBlob> is available
# Info in <TCanvas::Print>: pdf file test_myphoton.pdf has been created
# Info in <TCanvas::Print>: pdf file test_cleanedjets.pdf has been created
